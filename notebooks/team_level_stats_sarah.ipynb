# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('C:\ADS2001\Virtual Internships-20210323/virtualInternshipData_ADS2001.csv', encoding = "ISO-8859–1")
df = df[df["RoleName"] != "Mentor"]

# %%
df["global_group"] = df["implementation"] + df["group_id"].astype("string")

# %%
df
# Out:
#        Unnamed: 0  userIDs implementation  Line_ID ChatGroup  \
# 5               6        2              a        6     PRNLT
# 6               7        3              a        7     PRNLT
# 7               8        3              a        8     PRNLT
# 8               9        4              a        9     PRNLT
# 9              10        5              a       10     PRNLT
# ...           ...      ...            ...      ...       ...
# 19173       19174      391              o    19177    PESPVP
# 19174       19175      389              o    19178    PESPVP
# 19175       19176      392              o    19179    PESPVP
# 19176       19177      388              o    19180    PESPVP
# 19178       19179      393              o    19182    PESPVP
#
#                    content  group_id RoleName  \
# 5      Hello I am Brandon!         2   Player
# 6               I am Zelin         2   Player
# 7                       Hi         2   Player
# ...

# %%
grouped = df.groupby(["implementation", "group_id"])

# %%
grouped.describe()
# Out:
#                         Unnamed: 0                                     \
#                              count          mean         std      min
# implementation group_id
# a              2             299.0    186.474916   94.665830      6.0
#                3             170.0    465.494118   59.170924    351.0
#                4             274.0    732.872263   86.921727    562.0
#                5             192.0   1006.161458   61.243228    885.0
#                6             267.0   1273.835206   81.224157   1116.0
# ...                            ...           ...         ...      ...
# o              2             350.0  17761.134286  105.750323  17575.0
#                3             293.0  18108.535836   89.782249  17949.0
#                4             200.0  18383.175000   63.510648  18272.0
#                5             338.0  18680.739645  102.556854  18500.0
#                6             292.0  19022.756849   88.804309  18866.0
#
# ...

# %%
grouped.mean()
# Out:
#                            Unnamed: 0     userIDs       Line_ID  \
# implementation group_id
# a              2           186.474916    5.066890    186.474916
#                3           465.494118   11.135294    465.494118
#                4           732.872263   17.806569    732.872263
#                5          1006.161458   25.531250   1006.161458
#                6          1273.835206   31.704120   1273.835206
# ...                               ...         ...           ...
# o              2         17761.134286  369.591429  17764.134286
#                3         18108.535836  374.887372  18111.535836
#                4         18383.175000  379.890000  18386.175000
#                5         18680.739645  384.958580  18683.739645
#                6         19022.756849  390.736301  19025.756849
#
#                          m_experimental_testing  m_making_design_choices  \
# implementation group_id
# ...

# %% [markdown]
# ## Per Message (Rows)

# %%
df.groupby("implementation").hist("OutcomeScore");

# %%
df.groupby("implementation").hist("wordCount");

# %% [markdown]
# ## By User

# %%
get_number = lambda letter : ord(letter) - 96
df["implementation_num"] = df["implementation"].apply(get_number)

# %%
#df.groupby("userIDs").hist("OutcomeScore");
users = df.groupby("userIDs")
users_means = users.mean()
users_means
# Out:
#            Unnamed: 0       Line_ID  group_id  m_experimental_testing  \
# userIDs
# 2          189.015385    189.015385       2.0                0.030769
# 3          127.090909    127.090909       2.0                0.045455
# 4          208.193548    208.193548       2.0                0.064516
# 5          208.555556    208.555556       2.0                0.000000
# 6          182.162162    182.162162       2.0                0.000000
# ...               ...           ...       ...                     ...
# 389      19011.108696  19014.108696       6.0                0.043478
# 390      19023.895833  19026.895833       6.0                0.000000
# 391      19027.352941  19030.352941       6.0                0.039216
# 392      19023.333333  19026.333333       6.0                0.055556
# 393      19020.611111  19023.611111       6.0                0.069444
#
#          m_making_design_choices  m_asking_questions  \
# userIDs
# ...

# %%
users_means.groupby("implementation_num").hist("OutcomeScore");

# %%
users_means.groupby("implementation_num").hist("wordCount");
